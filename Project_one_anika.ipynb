# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
mass_shootings_path = "Resources/mass_shootings.csv"

mass_shootings_df = pd.read_csv(mass_shootings_path)

mass_shootings_df.head()
# Out:
#    Incident ID      Incident Date       State  City Or County  \
# 0       271363  December 29, 2014   Louisiana     New Orleans
# 1       269679  December 27, 2014  California     Los Angeles
# 2       270036  December 27, 2014  California      Sacramento
# 3       269167  December 26, 2014    Illinois  East St. Louis
# 4       268598  December 24, 2014    Missouri     Saint Louis
#
#                                Address  # Killed  # Injured
# 0                  Poydras and Bolivar         0          4
# 1  8800 block of South Figueroa Street         1          3
# 2             4000 block of May Street         0          4
# 3          2500 block of Summit Avenue         1          3
# 4                        18th and Pine         1          3

# %%
mass_shootings_df.shape
# Out:
# (3609, 7)

# %%
def convert_date(date_string):
    date_object = pd.to_datetime(date_string)
    new_date = date_object.strftime("%Y-%m-%d")
    return new_date

# %%
state_count = mass_shootings_df.groupby(['State']).count()
state_count.head()
# Out:
#             Incident ID  Incident Date  City Or County  Address  # Killed  \
# State
# Alabama              95             95              95       95        95
# Alaska                5              5               5        5         5
# Arizona              37             37              37       37        37
# Arkansas             43             43              43       43        43
# California          340            340             340      340       340
#
#             # Injured
# State
# Alabama            95
# Alaska              5
# Arizona            37
# Arkansas           43
# California        340

# %%
incident_dates = mass_shootings_df["Incident Date"]
incident_dates
# Out:
# 0       December 29, 2014
# 1       December 27, 2014
# 2       December 27, 2014
# 3       December 26, 2014
# 4       December 24, 2014
#               ...
# 3604      January 6, 2015
# 3605      January 4, 2015
# 3606      January 4, 2015
# 3607      January 2, 2015
# 3608      January 1, 2015
# Name: Incident Date, Length: 3609, dtype: object

# %%
#nj_dates is a series
incident_dates = incident_dates.apply(lambda date_string: convert_date(date_string))
incident_dates
# Out:
# 0       2014-12-29
# 1       2014-12-27
# 2       2014-12-27
# 3       2014-12-26
# 4       2014-12-24
#            ...
# 3604    2015-01-06
# 3605    2015-01-04
# 3606    2015-01-04
# 3607    2015-01-02
# 3608    2015-01-01
# Name: Incident Date, Length: 3609, dtype: object

# %%
mass_shootings_fixed = mass_shootings_df.copy()
mass_shootings_fixed["Incident Date"] = incident_dates
mass_shootings_fixed
# Out:
#       Incident ID Incident Date       State  City Or County  \
# 0          271363    2014-12-29   Louisiana     New Orleans
# 1          269679    2014-12-27  California     Los Angeles
# 2          270036    2014-12-27  California      Sacramento
# 3          269167    2014-12-26    Illinois  East St. Louis
# 4          268598    2014-12-24    Missouri     Saint Louis
# ...           ...           ...         ...             ...
# 3604       274867    2015-01-06     Florida           Miami
# 3605       273535    2015-01-04    Virginia         Roanoke
# 3606       273397    2015-01-04       Texas          Dallas
# 3607       273965    2015-01-02     Georgia        Savannah
# 3608       272016    2015-01-01   Tennessee         Memphis
#
#                                   Address  # Killed  # Injured
# 0                     Poydras and Bolivar         0          4
# 1     8800 block of South Figueroa Street         1          3
# 2                4000 block of May Street         0          4
# 3             2500 block of Summit Avenue         1          3
# 4                           18th and Pine         1          3
# ...                                   ...       ...        ...
# 3604         1300 block of NW 62nd Street         1          3
# 3605               3634 Shenandoah Ave NW         2          4
# 3606            2000 block of Ben Hur St.         3          1
# 3607          500 block of W. 54th Street         1          4
# 3608                 I-240 and Poplar Ave         0          5
#
# [3609 rows x 7 columns]

# %%
all_incidents_df = pd.read_csv("Resources/all_incidents.csv")
all_incidents_df.head(10)
# Out:
#    incident_id        date           state         city  \
# 0      2314858  2022-05-28        Arkansas  Little Rock
# 1      2314409  2022-05-28        Colorado       Denver
# 2      2314498  2022-05-28        Missouri  Saint Louis
# 3      2314485  2022-05-28  South Carolina     Florence
# 4      2314483  2022-05-28      California   Carmichael
# 5      2314481  2022-05-28        Kentucky   Louisville
# 6      2314479  2022-05-28        Kentucky   Louisville
# 7      2314476  2022-05-28       Louisiana  Baton Rouge
# 8      2314468  2022-05-28  South Carolina   Charleston
# 9      2314321  2022-05-28         Georgia    Thomaston
#
#                          address  n_killed  n_injured
# 0       W 9th St and Broadway St         0          1
# 1          3300 block of Clay St         0          1
# 2  Page Blvd and Vandeventer Ave         0          1
# 3                   Old River Rd         0          2
# 4    4400 block of Manzanita Ave         1          0
# 5              400 block of M St         0          1
# 6         2100 block of Hale Ave         0          1
# 7   Coursey Blvd and Stumberg Ln         0          2
# 8           2363 Ashley River Rd         2          0
# 9                    205 Park Ln         1          2

# %%
all_incidents_df.shape
# Out:
# (472820, 7)

# %%
all_incidents_df = all_incidents_df.rename(columns={
    'state':"State",
    "incident_id": "Incident ID",
    "date":"Incident Date",
    "city":"City or County",
    "address":"Address",
    "n_killed":"# Killed",
    "n_injured":"# Injured"
})
all_incidents_df.head()
# Out:
#    Incident ID Incident Date           State City or County  \
# 0      2314858    2022-05-28        Arkansas    Little Rock
# 1      2314409    2022-05-28        Colorado         Denver
# 2      2314498    2022-05-28        Missouri    Saint Louis
# 3      2314485    2022-05-28  South Carolina       Florence
# 4      2314483    2022-05-28      California     Carmichael
#
#                          Address  # Killed  # Injured
# 0       W 9th St and Broadway St         0          1
# 1          3300 block of Clay St         0          1
# 2  Page Blvd and Vandeventer Ave         0          1
# 3                   Old River Rd         0          2
# 4    4400 block of Manzanita Ave         1          0

# %%
# gun_violence_archive_df = pd.read_csv("Resources/GunViolenceArchiveDataJan2014toJun2022.csv")
# gun_violence_archive_df

# %%
# gvadata_df = pd.read_csv("Resources/GVAData 1.1.14 to 6.15.22.csv")
# gvadata_df.head(10)

# %%
combined_incidents_df = pd.concat([mass_shootings_fixed,all_incidents_df],axis=0)
combined_incidents_df = combined_incidents_df.sort_values(by="Incident Date")
combined_incidents_df
# Out:
#         Incident ID Incident Date           State City Or County  \
# 472819       461105    2013-01-01    Pennsylvania            NaN
# 472817       478855    2013-01-01            Ohio            NaN
# 472818       460726    2013-01-01      California            NaN
# 472816       478925    2013-01-05        Colorado            NaN
# 472815       478959    2013-01-07  North Carolina            NaN
# ...             ...           ...             ...            ...
# 27          2314738    2022-05-28        Virginia            NaN
# 26          2314540    2022-05-28           Texas            NaN
# 25          2314279    2022-05-28    Pennsylvania            NaN
# 36          2314747    2022-05-28        New York            NaN
# 46          2314553    2022-05-28        Missouri            NaN
#
#                                           Address  # Killed  # Injured  \
# 472819  1506 Versailles Avenue and Coursin Street         0          4
# 472817                      1776 East 28th Street         1          3
# 472818               13500 block of Cerise Avenue         1          3
# 472816           16000 block of East Ithaca Place         4          0
# 472815                  307 Mourning Dove Terrace         2          2
# ...                                           ...       ...        ...
# 27          1300 block of George Washington Hwy N         0          1
# 26             E Vickery Blvd and Belzsie Terrace         0          1
# 25                                      N 50th St         1          0
# 36                                 769 Hendrix St         0          1
# 46                         3200 block of E 8th St         0          1
#
#        City or County
# 472819     Mckeesport
# 472817         Lorain
# 472818      Hawthorne
# 472816         Aurora
# 472815     Greensboro
# ...               ...
# 27         Chesapeake
# 26         Fort Worth
# 25       Philadelphia
# 36           Brooklyn
# 46        Kansas City
#
# [476429 rows x 8 columns]

# %%
nj_incidents = combined_incidents_df[combined_incidents_df["State"] == "New Jersey"]
nj_incidents = nj_incidents.sort_values(by="Incident Date")
nj_incidents
# Out:
#         Incident ID Incident Date       State City Or County  \
# 472755       486005    2013-05-02  New Jersey            NaN
# 472748       486244    2013-05-11  New Jersey            NaN
# 472744      1007785    2013-05-14  New Jersey            NaN
# 472696      1023908    2013-07-02  New Jersey            NaN
# 472679       490932    2013-07-13  New Jersey            NaN
# ...             ...           ...         ...            ...
# 417         2312134    2022-05-24  New Jersey            NaN
# 416         2311481    2022-05-24  New Jersey            NaN
# 277         2312575    2022-05-25  New Jersey            NaN
# 246         2313228    2022-05-26  New Jersey            NaN
# 208         2314574    2022-05-26  New Jersey            NaN
#
#                               Address  # Killed  # Injured  \
# 472755                 804 S. 16th St         0          5
# 472748                 Fremont Street         0          4
# 472744                   Delaware Ave         0          2
# 472696                      Dwight St         1          0
# 472679        1100 block of Deutz Ave         1          4
# ...                               ...       ...        ...
# 417     Communipaw Ave and W Side Ave         1          0
# 416                      705 S New Rd         0          1
# 277                        195 1st St         0          1
# 246                  1811 N Delsea Dr         1          0
# 208       4700 block of Westfield Ave         0          1
#
#                           City or County
# 472755                            Newark
# 472748                       Jersey City
# 472744                           Delanco
# 472696                       Jersey City
# 472679       Trenton (Hamilton Township)
# ...                                  ...
# 417                          Jersey City
# 416                              Absecon
# 277                               Newark
# 246                             Vineland
# 208     Pennsauken (Pennsauken Township)
#
# [10126 rows x 8 columns]

# %%
state_count_all_incidents = combined_incidents_df.groupby(['State']).count()
state_count_all_incidents
# Out:
#                       Incident ID  Incident Date  City Or County  Address  \
# State
# Alabama                     10818          10818              95    10265
# Alaska                       1926           1926               5     1485
# Arizona                      5280           5280              37     5009
# Arkansas                     5628           5628              43     5213
# California                  31085          31085             340    30205
# Colorado                     6498           6498              52     6169
# Connecticut                  6124           6124              27     5739
# Delaware                     3162           3162              17     3084
# District of Columbia         6761           6761              59     6587
# Florida                     26838          26838             218    25321
# Georgia                     16389          16389             137    15633
# Hawaii                        550            550               0      480
# Idaho                        1137           1137               2      954
# Illinois                    36188          36188             374    35435
# Indiana                     11758          11758              75    11183
# Iowa                         4546           4546              18     4194
# Kansas                       4144           4144              21     3880
# Kentucky                     8503           8503              42     8001
